# %% [markdown]
# <a href="https://colab.research.google.com/github/kluckysingh/Number-guessing-game-in-Python-3/blob/main/Number_guessing_game_in_Python_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
print("Hi! Welcome to the Number Guessing Game.\nYou have 7 chances to guess the number. Let's start!")

low = int(input("Enter the lower Bound: "))
high = int(input("Enter the upper Bound: "))

print(f"\nYou have 7 chances to guess the number between {low} and {high}. Let's start!")

num = random.randint(low, high)
ch = 7
gc = 0

while gc < ch:
  gc = gc + 1
  guess = int(input('Enter your guess: '))

  if guess == num:
    print(f'Correct! The number is {num}. You guessed it in {gc} attempts.')
    break

  elif gc >= ch and guess != num:
    print(f'Sorry! The number was {num}. Better luck next time.')

  elif guess > num:
    print('To high! Try again.')

  elif guess < num:
    print('To low! Try again.')
# Out:
# Hi! Welcome to the Number Guessing Game.
# You have 7 chances to guess the number. Let's start!
# Enter the lower Bound: 2
# Enter the upper Bound: 20
#
# You have 7 chances to guess the number between 2 and 20. Let's start!
# Enter your guess: 3
# To low! Try again.
# Enter your guess: 5
# To low! Try again.
